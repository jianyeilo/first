# %% [markdown]
# <a href="https://colab.research.google.com/github/jianyeilo/first/blob/main/%E6%83%85%E5%A0%B1%E6%BC%94%E7%BF%92%E8%AA%B2%E9%A1%8Creport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def gcd(x,y) :
  while x != 0 :
    x , y = y % x , x
  return y

# %%
def egcd(x,y) :
  g = gcd(x,y)   # find (u,v)  u * x + v * y = g
  while x != 0 :




  return (g,(u,v))

# %%
def egcd2(x, y):
    while x != 0 :
        g, (u, v) = egcd(y % x, x)
        return g, (v - (y // x) * u, u)

# %%
egcd(2024,1015)
# Out:
# (1, (169, -337))

# %%
def egcd(x, y):
    if x == 0:
        return y, (0, 1)
    else:
        g, (u, v) = egcd(y % x, x)
        return g, (v - (y // x) * u, u)

# %%
def egcd1(x,y) :
  X , Y = x , y
  list = [ 1,0 ]
  while x != 0 :
    x , y , q = y % x , x , y//x
    list = [ -q * list[0] + list[1] , list[0] ]
  return (y ,( list[1], (y - list[1]*X) // Y))

# %%
egcd(2024,1015)
# Out:
# (1, (169, -337))

# %%
  egcd(1029,344)
# Out:
# (1, (-115, 344))

# %%
egcd(1,1)
# Out:
# (1, (1, 0))

# %%
egcd(21,56)
# Out:
# (7, (3, -1))
